# %% [markdown]
# <a href="https://colab.research.google.com/github/muntzar313/My-Data-Science-Journey/blob/main/EDA_excersize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing library


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#converting the file from Xlxs to csv & importing the data
excel_file=pd.read_excel('census_data.xlsx')
excel_file.to_csv('census_data.csv',index=None,header=True)
df=pd.read_csv('census_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3138 entries, 0 to 3137
# Data columns (total 45 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Unnamed: 0                                                                   3134 non-null   object
#  1   Unnamed: 1                                                                   3134 non-null   object
#  2   Unnamed: 2                                                                   3134 non-null   object
#  3   Unnamed: 3                                                                   3133 non-null   object
#  4   Unnamed: 4                                                                   3135 non-null   object
#  5   C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  3134 non-null   object
# ...

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      Table      State     Distt.  Area Name     Total/
# 1       Name       Code       Code        NaN     Rural/
# 2        NaN        NaN        NaN        NaN     Urban/
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#
#   C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  \
# 0                                          Age-group
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  1
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 35  \
# 0      Total        NaN        NaN  Illiterate  ...         NaN
# 1        NaN        NaN        NaN         NaN  ...         NaN
# 2        NaN        NaN        NaN         NaN  ...         NaN
# ...
